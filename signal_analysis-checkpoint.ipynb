# %% [raw]
# scipy.io.wavfile
# A part of the SciPy library, which provides easy reading and writing of WAV files.
# Installation: pip install scipy
#
# from scipy.io import wavfile
# sample_rate, data = wavfile.read('data/AS/New_AS_001.wav')
#
#
# wave
# A built-in Python library to read and write WAV files. It provides low-level access to WAV file headers.
# No installation required (since it is part of the Python standard library).
#
# import wave
# with wave.open('data/AS/New_AS_001.wav', 'rb') as wav_file:
#     sample_rate = wav_file.getframerate()
#     num_frames = wav_file.getnframes()
#     num_channels = wav_file.getnchannels()
#     data = wav_file.readframes(num_frames)
#
#
# pydub
# A high-level library that makes it easy to work with audio files, including WAV. It also supports conversion between various formats.
# Installation: pip install pydub
# from pydub import AudioSegment
# sound = AudioSegment.from_wav('data/AS/New_AS_001.wav')
# sample_rate = sound.frame_rate
# duration = len(sound) / 1000  # duration in seconds
# channels = sound.channels
#
#
# audioread
# A library to handle decoding of various audio formats including WAV. It provides a simpler interface for reading audio data.
# Installation: pip install audioread
#
# import audioread
# with audioread.audio_open('data/AS/New_AS_001.wav') as audio_file:
#     sample_rate = audio_file.samplerate
#     channels = audio_file.channels
#     duration = audio_file.duration
#
#
# librosa
# A popular library for analyzing audio signals, including WAV files. It’s great for music and speech analysis, featuring a lot of functionality like waveform visualization, feature extraction, etc.
# Installation: pip install librosa
#
# import librosa
# y, sr = librosa.load('data/AS/New_AS_001.wav', sr=None)  # sr=None to preserve original sample rate
# duration = librosa.get_duration(y=y, sr=sr)
#
#
# soundfile (PySoundFile)
# A Python library that allows reading and writing of sound files in a variety of formats, including WAV. It’s more flexible than scipy.io.wavfile.
# Installation: pip install soundfile
#
#
# Summary:
# For basic reading and writing of WAV files, you can use scipy.io.wavfile, wave, or soundfile.
# For audio analysis and feature extraction, librosa, pydub, and audioread are excellent choices.
# For real-time audio I/O and streaming, consider using pyaudio.
# All of these libraries provide different levels of abstraction and functionality depending on your use case.

# %%
import matplotlib.pyplot as plt
import soundfile as sf
import numpy as np

# Function to plot signal with a label
def plot_signal(time, signal, title, ax):
    ax.plot(time, signal, label=title)
    ax.set_title(title)
    ax.set_xlabel('Time [s]')
    ax.set_ylabel('Amplitude')
    ax.legend()

# Step 1: Read WAV files
file_paths = [
    ('Normal', 'data/N/New_N_001.wav'),
    ('Aortic Stenosis (AS)', 'data/AS/New_AS_001.wav'),
    ('Mitral Stenosis (MS)', 'data/MS/New_MS_001.wav'),
    ('Mitral Valve Prolapse (MVP)', 'data/MVP/New_MVP_001.wav'),
    ('Mitral Regurgitation (MR)', 'data/MR/New_MR_001.wav')
]

# Plot configuration
fig, axes = plt.subplots(len(file_paths), 1, figsize=(10, 12), sharex=True)

# Step 2: Loop through the files, read, and plot
for i, (label, file_path) in enumerate(file_paths):
    signal, sample_rate = sf.read(file_path)
    time = np.linspace(0, len(signal) / sample_rate, num=len(signal))  # Create time axis
    plot_signal(time, signal, f'{label}', axes[i])

# Step 3: Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Signal Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Step 1: Load the .wav file
sample_rate, data = wavfile.read('data/AS/New_AS_001.wav')

# Print general information
print(f"Sample Rate: {sample_rate} Hz")
print(f"Data shape: {data.shape}")
print(f"Duration: {data.shape[0] / sample_rate} seconds")

# Step 2: Plot the time-domain signal (Amplitude vs Time)
time = np.linspace(0, data.shape[0] / sample_rate, num=data.shape[0])

plt.figure(figsize=(10, 4))
plt.plot(time, data)
plt.title("Time-domain Signal")
plt.xlabel("Time [seconds]")
plt.ylabel("Amplitude")
# plt.grid(True)
plt.show()
# Out:
# Sample Rate: 8000 Hz
# Data shape: (20849,)
# Duration: 2.606125 seconds

# %%
# Step 1: Load the .wav file
sample_rate, data = wavfile.read('data/N/New_N_001.wav')

# Step 2: Get basic information about the data
num_samples = data.shape[0]  # Number of samples (time points)
num_channels = data.shape[1] if data.ndim > 1 else 1  # Check for stereo or mono
duration = num_samples / sample_rate  # Duration in seconds
sample_type = data.dtype  # Data type (e.g., int16, int32)

# Calculate the maximum and minimum amplitude values
max_amplitude = np.max(data)
min_amplitude = np.min(data)

# Step 3: Display information
print("==== Audio File Information ====")
print(f"Sample Rate: {sample_rate} Hz")
print(f"Number of Samples: {num_samples}")
print(f"Number of Channels: {num_channels}")
print(f"Duration: {duration:.2f} seconds")
print(f"Sample Type: {sample_type}")
print(f"Maximum Amplitude: {max_amplitude}")
print(f"Minimum Amplitude: {min_amplitude}")
print(f"Data Shape: {data.shape}")
print(f"Bit Depth: {data.itemsize * 8} bits")
# Out:
# ==== Audio File Information ====
# Sample Rate: 8000 Hz
# Number of Samples: 16837
# Number of Channels: 1
# Duration: 2.10 seconds
# Sample Type: int16
# Maximum Amplitude: 28116
# Minimum Amplitude: -24302
# Data Shape: (16837,)
# Bit Depth: 16 bits

# %% [markdown]
# ## FFT

# %%
# Step 3: Frequency analysis using FFT
# Perform FFT on the first channel (if stereo)
if data.ndim > 1:
    data = data[:, 0]

# Compute FFT
fft_data = np.fft.fft(data)
fft_freq = np.fft.fftfreq(len(fft_data), 1 / 1000)
fft_magnitude = np.abs(fft_data)

# Step 4: Find the dominant frequency
# Ignore the negative frequencies by considering only the positive frequencies
positive_freqs = fft_freq[:len(fft_freq)//2]
positive_magnitudes = fft_magnitude[:len(fft_magnitude)//2]

# Find the index of the maximum magnitude
dominant_freq_index = np.argmax(positive_magnitudes)

# Get the dominant frequency
dominant_freq = positive_freqs[dominant_freq_index]
dominant_magnitude = positive_magnitudes[dominant_freq_index]

# Print the dominant frequency
print(f"Dominant Frequency: {dominant_freq:.2f} Hz with magnitude {dominant_magnitude:.2f}")

# Step 5: Plot the frequency spectrum
plt.figure(figsize=(10, 4))
plt.plot(positive_freqs, positive_magnitudes)  # Plot positive frequencies
plt.title("Frequency Spectrum")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Magnitude")
plt.grid(True)
plt.show()
# Out:
# Dominant Frequency: 9.80 Hz with magnitude 17478034.94

# %% [markdown]
# ## STFT

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
from scipy.io import wavfile
import numpy as np

# Load the WAV file
sample_rate, data = wavfile.read('data/AS/New_AS_001.wav')

# Convert data to float (if it's not already in a floating-point format)
data = data.astype(float)

data = librosa.resample(data, orig_sr = sample_rate, target_sr = 1000)

# Compute the STFT
stft_result = librosa.stft(data)

# Convert amplitude to decibels
db_spectrogram = librosa.amplitude_to_db(abs(stft_result), ref=np.max)

# Plot the spectrogram
plt.figure(figsize=(12, 6))
librosa.display.specshow(db_spectrogram, sr=2000, x_axis='time', y_axis='hz', cmap='viridis')
plt.colorbar(format='%+2.0f dB')
plt.title('STFT Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.show()

# %% [markdown]
# ## DWT analysis

# %%
import pywt
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Load the WAV file
sample_rate, data = wavfile.read('data/AS/New_AS_001.wav')

# Normalize data to float (if needed)
data = data.astype(float)

data = librosa.resample(data, orig_sr = sample_rate, target_sr = 1000)

# Perform a 4-level DWT decomposition with 'db14'
wavelet = 'db14'
coeffs = pywt.wavedec(data, wavelet, level=4)

# Extract details and approximation coefficients
cA4, cD4, cD3, cD2, cD1 = coeffs

# Plot the coefficients
plt.figure(figsize=(15, 10))

# Plot D1
plt.subplot(5, 1, 1)
plt.plot(cD1, color='blue')
plt.title('Detail Coefficients - Level 1 (D1)')
plt.xlabel('Samples')
plt.ylabel('Amplitude')

# Plot D2
plt.subplot(5, 1, 2)
plt.plot(cD2, color='orange')
plt.title('Detail Coefficients - Level 2 (D2)')
plt.xlabel('Samples')
plt.ylabel('Amplitude')

# Plot D3
plt.subplot(5, 1, 3)
plt.plot(cD3, color='green')
plt.title('Detail Coefficients - Level 3 (D3)')
plt.xlabel('Samples')
plt.ylabel('Amplitude')

# Plot D4
plt.subplot(5, 1, 4)
plt.plot(cD4, color='red')
plt.title('Detail Coefficients - Level 4 (D4)')
plt.xlabel('Samples')
plt.ylabel('Amplitude')

# Plot A4
plt.subplot(5, 1, 5)
plt.plot(cA4, color='purple')
plt.title('Approximation Coefficients - Level 4 (A4)')
plt.xlabel('Samples')
plt.ylabel('Amplitude')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CWT

# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
from scipy.signal import resample
import pywt

# Step 1: Read the WAV file
file_path = 'data/AS/New_AS_001.wav'  # Replace with the actual path to your wav file
signal, sample_rate = sf.read(file_path)

# Step 2: Resample to 2kHz
new_sample_rate = 2000  # Resampling to 2 kHz
num_samples = int(len(signal) * new_sample_rate / sample_rate)
resampled_signal = resample(signal, num_samples)

# Step 3: Apply Continuous Wavelet Transform (CWT)
widths = np.arange(1, 128)  # Scale levels for CWT
cwt_coefficients, freqs = pywt.cwt(resampled_signal, widths, 'morl', sampling_period=1/new_sample_rate)

# Step 4: Plot CWT (Scalogram)
plt.figure(figsize=(10, 6))
plt.imshow(np.abs(cwt_coefficients), extent=[0, len(resampled_signal)/new_sample_rate, 1, 128], cmap='jet', aspect='auto')
plt.title('CWT Scalogram')
plt.xlabel('Time [s]')
plt.ylabel('Scale')
plt.colorbar(label='Magnitude')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## MFCC

# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
from scipy.signal import resample
import librosa
import librosa.display

# Step 1: Read the WAV file
file_path = 'data/AS/New_AS_001.wav'  # Replace with the actual path to your wav file
signal, sample_rate = sf.read(file_path)

# Step 2: Resample to 2kHz
new_sample_rate = 2000  # Resampling to 2 kHz
num_samples = int(len(signal) * new_sample_rate / sample_rate)
resampled_signal = resample(signal, num_samples)

# Step 3: Compute MFCCs
mfccs = librosa.feature.mfcc(y=resampled_signal.astype(float), sr=new_sample_rate, n_mfcc=13)

# Step 4: Plot MFCCs with custom y-axis labels (0 to 13)
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfccs, x_axis='time', sr=new_sample_rate)
plt.colorbar(label='MFCC Coefficients')
plt.title('MFCC Coefficients')
plt.ylabel('MFCC Coefficients')  # Y-axis label
plt.yticks(ticks=np.arange(0, 13), labels=np.arange(0, 13))  # Set y-ticks to show 0 to 13
plt.tight_layout()
plt.show()
